# %% [markdown]
# # Flow Of Project
# # 1 Import Data
# # 2 Proprocess Data
# # 3 Visualize Data
# # 4 Train test split
# # 5 Train Model and Avualivation
# # 6 Prediction System with Web app

# %% [markdown]
# # Import Necessary Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
medical_df = pd.read_csv('insurance.csv')

# %%
medical_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # About the Data:
# age: age of the insured person (numeric)
# sex: gender of the insured person (categorical: male/female)
# bmi: body mass index of the insured person (numeric)
# children: number of children covered by the insurance plan (numeric)
# smoker: whether or not the insured person is a smoker (categorical: yes/no)
# region: region where the insured person resides (categorical: northeast/northwest/southeast/southwest)
# charges: the insurance charges/costs billed to the insured person (numeric)

# %% [markdown]
# # Exploring Data & Analysing Data

# %%
medical_df.shape
# Out:
# (1338, 7)

# %%
medical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
medical_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize=(3,3))
sns.displot(data=medical_df,x='age')

# %%
plt.figure(figsize=(3,3))
sns.displot(data=medical_df,x='sex',kind='hist')

# %%
medical_df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
medical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
plt.figure(figsize=(4,4))
sns.displot(data=medical_df,x='bmi')
plt.show()

# %%
medical_df['bmi'].value_counts()
# Out:
# bmi
# 32.300    13
# 28.310     9
# 30.800     8
# 31.350     8
# 30.495     8
#           ..
# 20.350     1
# 31.240     1
# 19.095     1
# 22.100     1
# 21.280     1
# Name: count, Length: 548, dtype: int64

# %%
plt.figure(figsize=(4,4))
sns.countplot(medical_df['children'])
plt.show()

# %%
medical_df['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=medical_df,x='smoker')
plt.show()

# %%
medical_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # convert categorical column to numerical

# %%
medical_df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
medical_df.replace({'sex':{'male':0,'female':1}},inplace=True)
medical_df.replace({'smoker':{'yes':0,'no':1}},inplace=True)
medical_df.replace({'region':{'southeast':0,'southwest':1,'northwest':2,'northeast':3}},inplace=True)
# Out:
# C:\Users\dhads\AppData\Local\Temp\ipykernel_3020\3958717934.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medical_df.replace({'sex':{'male':0,'female':1}},inplace=True)
# C:\Users\dhads\AppData\Local\Temp\ipykernel_3020\3958717934.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medical_df.replace({'smoker':{'yes':0,'no':1}},inplace=True)
# C:\Users\dhads\AppData\Local\Temp\ipykernel_3020\3958717934.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medical_df.replace({'region':{'southeast':0,'southwest':1,'northwest':2,'northeast':3}},inplace=True)

# %%
medical_df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       0       1  16884.92400
# 1   18    0  33.770         1       1       0   1725.55230
# 2   28    0  33.000         3       1       0   4449.46200
# 3   33    0  22.705         0       1       2  21984.47061
# 4   32    0  28.880         0       1       2   3866.85520

# %% [markdown]
# # Train Test Split

# %%
X = medical_df.drop('charges',axis=1)
y = medical_df['charges']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

# %%
X_train.shape
# Out:
# (1204, 6)

# %%
X_test.shape
# Out:
# (134, 6)

# %%
lg = LinearRegression()
lg.fit(X_train,y_train) # 80 model will be train
y_pred = lg.predict(X_test) # 10 model will be predicted

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7058997983752827

# %% [markdown]
# # Prediction System

# %%
,input_df = ( 30,1, 25, 2, 1, 1) # Example: age, sex (1=female), bmi, children, smoker (1=no), region (1=southwest)
np_df = np.asarray(input_df)
input_df_reshaped = np_df.reshape(1,-1)
prediction = lg.predict(input_df_reshaped)
print(f"The insurance cost for the given input is: {prediction[0]:.2f}")
# Out:
# c:\Users\dhads\OneDrive\pyhon\ML_Project2\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# The insurance cost for the given input is: 4515.94
